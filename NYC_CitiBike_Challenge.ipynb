# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data.
# Load File
citibike_tripdata_load = "201908-citibike-tripdata/201908-citibike-tripdata.csv"

# %%
# Read CSV File
citibike_tripdata_df = pd.read_csv(citibike_tripdata_load)

# %%
citibike_tripdata_df.sample(5)
# Out:
#          tripduration                 starttime                  stoptime  \
# 531987           1822  2019-08-08 01:41:49.1230  2019-08-08 02:12:11.7330
# 892005            678  2019-08-12 16:52:57.2450  2019-08-12 17:04:15.3530
# 1212529           715  2019-08-16 16:31:10.7660  2019-08-16 16:43:06.5050
# 1219051           428  2019-08-16 17:25:00.6550  2019-08-16 17:32:09.3760
# 2111024           603  2019-08-28 19:40:00.2750  2019-08-28 19:50:03.6610
#
#          start station id           start station name  \
# 531987              484.0              W 44 St & 5 Ave
# 892005              479.0              9 Ave & W 45 St
# 1212529             518.0              E 39 St & 2 Ave
# 1219051             426.0        West St & Chambers St
# 2111024            3163.0  Central Park West & W 68 St
#
#          start station latitude  start station longitude  end station id  \
# 531987                40.755003               -73.980144           508.0
# ...

# %%
# 2. Check the datatypes of your columns. 
# citibike_tripdata_df['tripduration'].dtypes
citibike_tripdata_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
new_tripduration = pd.to_datetime(citibike_tripdata_df["tripduration"], unit='m')
new_tripduration
# Out:
# 0         1970-01-01 06:33:00
# 1         1970-01-01 10:27:00
# 2         1970-01-01 18:52:00
# 3         1970-01-02 05:40:00
# 4         1970-01-02 01:17:00
#                   ...
# 2344219   1970-01-01 03:36:00
# 2344220   1970-01-01 01:57:00
# 2344221   1970-01-02 02:54:00
# 2344222   1970-01-01 21:41:00
# 2344223   1970-01-01 06:59:00
# Name: tripduration, Length: 2344224, dtype: datetime64[ns]

# %%
citibike_tripdata_df["New_tripduration"] = pd.to_datetime(citibike_tripdata_df["tripduration"], unit='m')
# citibike_tripdata_df["tripduration"] = pd.to_datetime(citibike_tripdata_df["tripduration"], unit='m')

# %%
citibike_tripdata_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# ...

# %%
# 4. Check the datatypes of your columns. 
citibike_tripdata_df.dtypes
# Out:
# tripduration                        int64
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# New_tripduration           datetime64[ns]
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
export_csv = "citibike_tripdata.csv"
citibike_tripdata_df.to_csv(export_csv, index=False)
